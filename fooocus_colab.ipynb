# %% [markdown]
# <a href="https://colab.research.google.com/github/SUPERMASSlVE/Fooocus/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/SUPERMASSlVE/Fooocus
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 23.4 MB/s eta 0:00:00
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6718, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 6718 (delta 11), reused 22 (delta 8), pack-reused 6687 (from 1)
# Receiving objects: 100% (6718/6718), 33.27 MiB | 15.03 MiB/s, done.
# Resolving deltas: 100% (3871/3871), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# ...
